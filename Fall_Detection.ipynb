# %% [markdown]
# <a href="https://colab.research.google.com/github/Red-54/Fall_Detection/blob/main/Fall_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Training YOLO11 Object Detection Model on a Fall Dataset**

# %%
# !nvidia-smi
# Out:
# Thu Oct 10 09:06:48 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# **Step 01 # Install the Ultralytics Package**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 29.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Step 02 # Import All the Requried Libraries**

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.2/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# **Step # 03 Download Dataset from Roboflow**

# %%
# !curl -L "https://universe.roboflow.com/ds/5mwv7aatCg?key=WTvOYdr0hS" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/people-6536-_jpg.rf.d25fabfacfa0a924d9e02b5f3cb851af.txt
#   inflating: train/labels/people-6537-_jpg.rf.310c00893c831af35b846ec78e738f87.txt
#   inflating: train/labels/people-6537-_jpg.rf.a25ef8e2d065b86f856d559e2271872c.txt
#   inflating: train/labels/people-6537-_jpg.rf.e51fc6a4008794836e8d422bfe354edb.txt
#   inflating: train/labels/people-654-_jpg.rf.23bb03a16460a7d2fd8155887bb2e98f.txt
#   inflating: train/labels/people-654-_jpg.rf.613104350e6b0810f3074a32fdc1c015.txt
#   inflating: train/labels/people-654-_jpg.rf.9cbd7ed5df0cd3a7ca2d2c8319ef0462.txt
#   inflating: train/labels/people-6541-_jpg.rf.118c0a0380e8f7dd431b9b32bdcc9130.txt
#   inflating: train/labels/people-6541-_jpg.rf.a200aef966a893dcc6f709e37cd2283c.txt
#   inflating: train/labels/people-6541-_jpg.rf.fb94456f26c361f23d6209ecacae34e7.txt
#   inflating: train/labels/people-6542-_jpg.rf.89bd2dd6d24f7379615bb239fdac0c09.txt
# ...

# %% [markdown]
# **Step # 04 Train YOLO11 Model on a Custom Dataset**

# %%
# !yolo task=detect mode=train data=/content/data.yaml model="yolo11n.pt" epochs=25 imgsz=640
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **Step # 05 Examine Training Results**

# %%
Image("/content/runs/detect/train2/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train2/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train2/results.png", width=600)

# %%
Image("/content/runs/detect/train2/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train2/val_batch0_pred.jpg", width=600)

# %%
Image("/content/runs/detect/train2/val_batch1_pred.jpg", width=600)
